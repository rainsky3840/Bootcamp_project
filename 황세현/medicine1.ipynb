# %% [markdown]
# # 구글 드라이브 마운드

# %%
#google drive 연결
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 라이브러리 import

# %%
#import lib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import tensorflow
import torch
import pandas
import seaborn as sns

import glob #파일명 다 긁어오기
import PIL
import cv2 #이미지 데이터 전처리, 이미지 불러오기

import imageio #이미지 불러오기
import skimage # Numpy배열로 이미지 객체를 다룬다.
import skimage.io
import skimage.transform

from sklearn.model_selection import train_test_split

# %% [markdown]
# # csv 파일 읽어오기
# - csv: 데이터 폴더 엑셀화한 문서

# %%
df = pd.read_csv('/content/drive/MyDrive/SWBootcamp_Personal/DataSet.csv')

# %%
df.sample(100).head()
# Out:
#                                  Name Extension     Date accessed  \
# 9229  K-039147_0_2_0_0_75_260_200.png      .png  2021-09-07 16:24
# 5226  K-039104_0_0_1_1_75_120_200.png      .png  2021-10-06 11:43
# 563   K-038896_0_1_0_2_75_100_200.png      .png  2021-11-10 12:31
# 3593  K-038967_0_2_0_0_75_220_200.png      .png  2021-11-26 10:18
# 8991  K-039147_0_1_1_0_70_180_200.png      .png  2021-09-07 16:22
#
#          Date modified      Date created  \
# 9229  2021-09-07 16:24  2021-09-07 16:24
# 5226  2021-10-06 11:43  2021-10-06 11:43
# 563   2021-11-10 12:31  2021-11-10 12:31
# 3593  2021-11-26 10:18  2021-11-26 10:18
# 8991  2021-09-07 16:22  2021-09-07 16:22
#
#                                             Folder Path
# 9229  D:\SW BootCamp\개인프로젝트\[2. 약 분류]\data\166.약품식별 ...
# 5226  D:\SW BootCamp\개인프로젝트\[2. 약 분류]\data\166.약품식별 ...
# 563   D:\SW BootCamp\개인프로젝트\[2. 약 분류]\data\166.약품식별 ...
# 3593  D:\SW BootCamp\개인프로젝트\[2. 약 분류]\data\166.약품식별 ...
# 8991  D:\SW BootCamp\개인프로젝트\[2. 약 분류]\data\166.약품식별 ...

# %%
df.head()
# Out:
#                               Name Extension     Date accessed  \
# 0  K-038884_0_0_0_0_75_000_200.png      .png  2023-01-10 16:55
# 1  K-038884_0_0_0_0_75_020_200.png      .png  2023-01-10 16:55
# 2  K-038884_0_0_0_0_75_040_200.png      .png  2023-01-10 16:55
# 3  K-038884_0_0_0_0_75_060_200.png      .png  2023-01-10 16:55
# 4  K-038884_0_0_0_0_75_080_200.png      .png  2023-01-10 16:55
#
#       Date modified      Date created  \
# 0  2021-10-07 10:48  2021-10-07 10:48
# 1  2021-10-07 10:48  2021-10-07 10:48
# 2  2021-10-07 10:48  2021-10-07 10:48
# 3  2021-10-07 10:48  2021-10-07 10:48
# 4  2021-10-07 10:48  2021-10-07 10:48
#
#                                          Folder Path
# 0  D:\SW BootCamp\개인프로젝트\[2. 약 분류]\data\166.약품식별 ...
# 1  D:\SW BootCamp\개인프로젝트\[2. 약 분류]\data\166.약품식별 ...
# 2  D:\SW BootCamp\개인프로젝트\[2. 약 분류]\data\166.약품식별 ...
# 3  D:\SW BootCamp\개인프로젝트\[2. 약 분류]\data\166.약품식별 ...
# 4  D:\SW BootCamp\개인프로젝트\[2. 약 분류]\data\166.약품식별 ...

# %%
df
# Out:
#                                  Name Extension     Date accessed  \
# 0     K-038884_0_0_0_0_75_000_200.png      .png  2023-01-10 16:55
# 1     K-038884_0_0_0_0_75_020_200.png      .png  2023-01-10 16:55
# 2     K-038884_0_0_0_0_75_040_200.png      .png  2023-01-10 16:55
# 3     K-038884_0_0_0_0_75_060_200.png      .png  2023-01-10 16:55
# 4     K-038884_0_0_0_0_75_080_200.png      .png  2023-01-10 16:55
# ...                               ...       ...               ...
# 9607  K-039147_0_2_1_2_90_260_200.png      .png  2021-09-07 16:25
# 9608  K-039147_0_2_1_2_90_280_200.png      .png  2021-09-07 16:25
# 9609  K-039147_0_2_1_2_90_300_200.png      .png  2021-09-07 16:25
# 9610  K-039147_0_2_1_2_90_320_200.png      .png  2021-09-07 16:25
# 9611  K-039147_0_2_1_2_90_340_200.png      .png  2021-09-07 16:25
#
#          Date modified      Date created  \
# 0     2021-10-07 10:48  2021-10-07 10:48
# 1     2021-10-07 10:48  2021-10-07 10:48
# 2     2021-10-07 10:48  2021-10-07 10:48
# 3     2021-10-07 10:48  2021-10-07 10:48
# 4     2021-10-07 10:48  2021-10-07 10:48
# ...                ...               ...
# 9607  2021-09-07 16:25  2021-09-07 16:25
# 9608  2021-09-07 16:25  2021-09-07 16:25
# 9609  2021-09-07 16:25  2021-09-07 16:25
# 9610  2021-09-07 16:25  2021-09-07 16:25
# 9611  2021-09-07 16:25  2021-09-07 16:25
#
#                                             Folder Path
# 0     D:\SW BootCamp\개인프로젝트\[2. 약 분류]\data\166.약품식별 ...
# 1     D:\SW BootCamp\개인프로젝트\[2. 약 분류]\data\166.약품식별 ...
# 2     D:\SW BootCamp\개인프로젝트\[2. 약 분류]\data\166.약품식별 ...
# 3     D:\SW BootCamp\개인프로젝트\[2. 약 분류]\data\166.약품식별 ...
# 4     D:\SW BootCamp\개인프로젝트\[2. 약 분류]\data\166.약품식별 ...
# ...                                                 ...
# 9607  D:\SW BootCamp\개인프로젝트\[2. 약 분류]\data\166.약품식별 ...
# 9608  D:\SW BootCamp\개인프로젝트\[2. 약 분류]\data\166.약품식별 ...
# 9609  D:\SW BootCamp\개인프로젝트\[2. 약 분류]\data\166.약품식별 ...
# 9610  D:\SW BootCamp\개인프로젝트\[2. 약 분류]\data\166.약품식별 ...
# 9611  D:\SW BootCamp\개인프로젝트\[2. 약 분류]\data\166.약품식별 ...
#
# [9612 rows x 6 columns]

# %% [markdown]
# # DataFrame 파일명, 종류로 정리

# %%
df['Name'] = df['Name'].astype('str')
df['Name'].dtypes

Name_list = df['Name'].str.split('_')
Name_list.head()

df['kind'] = Name_list.str.get(0)
df.head()
# Out:
#                               Name Extension     Date accessed  \
# 0  K-038884_0_0_0_0_75_000_200.png      .png  2023-01-10 16:55
# 1  K-038884_0_0_0_0_75_020_200.png      .png  2023-01-10 16:55
# 2  K-038884_0_0_0_0_75_040_200.png      .png  2023-01-10 16:55
# 3  K-038884_0_0_0_0_75_060_200.png      .png  2023-01-10 16:55
# 4  K-038884_0_0_0_0_75_080_200.png      .png  2023-01-10 16:55
#
#       Date modified      Date created  \
# 0  2021-10-07 10:48  2021-10-07 10:48
# 1  2021-10-07 10:48  2021-10-07 10:48
# 2  2021-10-07 10:48  2021-10-07 10:48
# 3  2021-10-07 10:48  2021-10-07 10:48
# 4  2021-10-07 10:48  2021-10-07 10:48
#
#                                          Folder Path      kind
# 0  D:\SW BootCamp\개인프로젝트\[2. 약 분류]\data\166.약품식별 ...  K-038884
# 1  D:\SW BootCamp\개인프로젝트\[2. 약 분류]\data\166.약품식별 ...  K-038884
# 2  D:\SW BootCamp\개인프로젝트\[2. 약 분류]\data\166.약품식별 ...  K-038884
# 3  D:\SW BootCamp\개인프로젝트\[2. 약 분류]\data\166.약품식별 ...  K-038884
# 4  D:\SW BootCamp\개인프로젝트\[2. 약 분류]\data\166.약품식별 ...  K-038884

# %%
del df['Extension']
del df['Date accessed']
del df['Date modified']
del df['Date created']
del df['Folder Path']
df
# Out:
#                                  Name      kind
# 0     K-038884_0_0_0_0_75_000_200.png  K-038884
# 1     K-038884_0_0_0_0_75_020_200.png  K-038884
# 2     K-038884_0_0_0_0_75_040_200.png  K-038884
# 3     K-038884_0_0_0_0_75_060_200.png  K-038884
# 4     K-038884_0_0_0_0_75_080_200.png  K-038884
# ...                               ...       ...
# 9607  K-039147_0_2_1_2_90_260_200.png  K-039147
# 9608  K-039147_0_2_1_2_90_280_200.png  K-039147
# 9609  K-039147_0_2_1_2_90_300_200.png  K-039147
# 9610  K-039147_0_2_1_2_90_320_200.png  K-039147
# 9611  K-039147_0_2_1_2_90_340_200.png  K-039147
#
# [9612 rows x 2 columns]

# %% [markdown]
# # 약 종류 별 개수 출력

# %%
df['kind'].value_counts()
# Out:
# K-039147    1296
# K-039146    1296
# K-039136    1296
# K-038954     324
# K-039047     324
# K-039036     324
# K-039021     324
# K-038967     324
# K-038958     324
# K-038962     324
# K-038929     324
# K-038927     324
# K-038910     324
# K-038896     324
# K-038959     216
# K-038890     216
# K-038970     216
# K-038914     216
# K-038913     216
# K-038912     216
# K-039104     216
# K-039108     216
# K-039123     216
# K-038884     216
# Name: kind, dtype: int64

# %%
#kind
plt.figure(figsize=(24,8))
sns.countplot(df['kind'])
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 이미지 확인

# %%
IMAGE_PATH = '/content/drive/MyDrive/SWBootcamp_Personal/images'

# image_kinds = 실제 이미지 파일 상단 폴더명 모음
image_kinds = list(os.listdir(IMAGE_PATH))
print(image_kinds) #24개
print('image_files len: ' + str(len(image_kinds)))

# image_files = 실제 이미지들 모음
image_files = list(os.listdir(IMAGE_PATH +'/'+ str(image_kinds[0])))
print(image_files)
for i in range(1, len(image_kinds)):
  # image_files.append(os.listdir(IMAGE_PATH +'/'+ str(image_kinds[i])))
  image_file_tmp = list(os.listdir(IMAGE_PATH +'/'+ str(image_kinds[i])))
  image_files = image_files + image_file_tmp
  print('image_files len: ' + str(len(image_files)))

print(image_files)



print("Number of image files: {}".format(len(image_files)))
# Out:
# ['K-038884', 'K-039147', 'K-039146', 'K-039136', 'K-039108', 'K-039104', 'K-039047', 'K-039036', 'K-039021', 'K-038970', 'K-038967', 'K-038962', 'K-038959', 'K-039123', 'K-038958', 'K-038954', 'K-038929', 'K-038927', 'K-038914', 'K-038913', 'K-038912', 'K-038910', 'K-038896', 'K-038890']
# image_files len: 24
# ['K-038884_0_0_0_0_90_260_200.png', 'K-038884_0_0_0_0_90_280_200.png', 'K-038884_0_0_0_0_90_240_200.png', 'K-038884_0_0_0_0_90_140_200.png', 'K-038884_0_0_0_0_90_200_200.png', 'K-038884_0_0_0_0_90_180_200.png', 'K-038884_0_0_0_0_90_160_200.png', 'K-038884_0_0_0_0_90_220_200.png', 'K-038884_0_0_0_0_90_100_200.png', 'K-038884_0_0_0_0_90_120_200.png', 'K-038884_0_0_0_0_90_080_200.png', 'K-038884_0_0_0_0_90_060_200.png', 'K-038884_0_0_0_0_75_260_200.png', 'K-038884_0_0_0_0_75_320_200.png', 'K-038884_0_0_0_0_75_300_200.png', 'K-038884_0_0_0_0_75_240_200.png', 'K-038884_0_0_0_0_75_280_200.png', 'K-038884_0_0_0_0_75_340_200.png', 'K-038884_0_0_0_0_90_020_200.png', 'K-038884_0_0_0_0_90_000_200.png', 'K-038884_0_0_0_0_90_040_200.png', 'K-038884_0_0_0_0_75_220_200.png', 'K-038884_0_0_0_0_75_020_200.png', 'K-038884_0_0_0_0_75_080_200.png', 'K-038884_0_0_0_0_75_060_200.png', 'K-038884_0_0_0_0_75_040_200.png', 'K-038884_0_0_0_0_75_100_
200.png', 'K-038884_0_0_0_2_90_160_200.png', 'K-038884_0_0_0_2_90_220_200.png', 'K-038884_0_0_0_2_90_200_200.png', 'K-038884_0_0_0_2_90_120_200.png', 'K-038884_0_0_0_2_90_140_200.png', 'K-038884_0_0_0_2_90_100_200.png', 'K-038884_0_0_0_2_90_040_200.png', 'K-038884_0_0_0_2_90_180_200.png', 'K-038884_0_0_0_2_90_080_200.png', 'K-038884_0_0_0_2_90_060_200.png', 'K-038884_0_0_0_2_90_020_200.png', 'K-038884_0_0_0_2_75_180_200.png', 'K-038884_0_0_0_2_75_260_200.png', 'K-038884_0_0_0_2_75_280_200.png', 'K-038884_0_0_0_2_75_300_200.png', 'K-038884_0_0_0_2_75_240_200.png', 'K-038884_0_0_0_2_75_220_200.png', 'K-038884_0_0_0_2_90_000_200.png', 'K-038884_0_0_0_2_75_340_200.png', 'K-038884_0_0_0_2_75_160_200.png', 'K-038884 ...
# Number of image files: 9632

# %%
file_names = list(df['Name']) #df의 'file' 칼럼 데이터로 리스트 생성 (파일명)

#file_names로 집합을 만들고, image file 이름과 매칭시킨 개수를 구한다.
print("Matching image names: {}".format(len(set(file_names).intersection(image_files))))
# Out:
# Matching image names: 9612

# %%
#이미지 그리는 함수
def draw_category_images(var,cols=5):
    categories = (df.groupby([var])[var].nunique()).index
    f, ax = plt.subplots(nrows=len(categories),ncols=cols, figsize=(2*cols,2*len(categories)))
    # draw a number of images for each location
    for i, cat in enumerate(categories):
        sample = df[df[var]==cat].sample(cols)
        for j in range(0,cols):
            file = IMAGE_PATH + '/' + sample.iloc[j]['kind'] + '/' + sample.iloc[j]['Name']
            im=imageio.imread(file)
            ax[i, j].imshow(im, resample=True)
            ax[i, j].set_title(cat, fontsize=9)  
    plt.tight_layout()
    plt.show()

# %%
draw_category_images('kind')  # 24종류 -> 24행 * 5열
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # train/test set 준비

# %%
#train set:test set = 0.8:0.2
train_df, test_df = train_test_split(df, test_size=0.2, random_state=1, stratify=df['kind'])

# %%
#이미지 경로에서 읽어오기 (size:200*200)
def read_image(file_name):
  image = skimage.io.imread(IMAGE_PATH + file_name) # 경로 + 파일명
  image = skimage.transform.resize(image, (200, 200), mode='reflect')
  return image[:,:,:3]

# %%
def categories_encoder(dataset, var):
    #file명을 읽어 이미지 경로에서 불러온다. X 값.
    X = np.stack(dataset['file'].apply(read_image))
    # subspecies를 더미변수화 하여 y값으로
    y = pd.get_dummies(dataset[var], drop_first=False)
    return X, y

# %%
#file명을 읽어 이미지 경로에서 불러온다. X 값.
X_train, y_train = categories_encoder(train_df, 'subspecies')
X_test, y_test = categories_encoder(test_df, 'subspecies')

# %%
#개수, size, channel
print(X_train.shape) # (trainset 개수, 크기,크기,rgb)
print(y_train.shape) # (trainset 개수, 몇 개의 subspecies)
print(X_test.shape) # (testset 개수, 크기,크기,rgb)
print(y_test.shape) # (testset 개수, 몇 개의 subspecies)
