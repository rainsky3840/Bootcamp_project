# %% [markdown]
# <a href="https://colab.research.google.com/github/ongsim0629/Bootcamp_project/blob/main/2%EC%9D%BC%EC%B0%A8_%EA%B2%BD%EA%B5%AC%EC%95%BD%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 구글 드라이브 내 폴더 접근근
# 리눅스 명령어로 zip 파일 경로 지정 후 압축 해제
from google.colab import drive
drive.mount('/content/drive')

! unzip -uq "/content/drive/MyDrive/TL_4_조합.zip" -d "/content/label"
! unzip -uq "/content/drive/MyDrive/TS_4_조합.zip" -d "/content/image"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
label_mother_path = '/content/label'
image_mother_path = '/content/image'
label_folder_list = os.listdir(label_mother_path)
image_folder_list = os.listdir(image_mother_path)

# 폴더 이름순 정렬
label_folder_list.sort()
image_folder_list.sort()

print(label_folder_list)
print(image_folder_list)


# folder_A = os.listdir(mother_path+'/'+folder_list[0])
# print(folder_A)
# # for folder in folder_list:
# #     print(mother_path + folder)
# Out:
# ['K-004378-005002-005094-019552_json', 'K-004378-005002-005094-022627_json', 'K-004378-005002-005094-023223_json', 'K-004378-005002-006192-025438_json', 'K-004378-005002-012778-025438_json', 'K-004378-005002-019552-025438_json', 'K-004378-005002-022627-025438_json', 'K-004378-005002-023223-025438_json', 'K-004378-005094-006192-013161_json', 'K-004378-005094-006192-037777_json', 'K-004378-005094-006192-038954_json', 'K-004378-005094-006192-044834_json', 'K-004378-005094-012778-013161_json', 'K-004378-005094-012778-037777_json', 'K-004378-005094-012778-038954_json', 'K-004378-005094-012778-044834_json', 'K-004378-005094-013161-019552_json', 'K-004378-005094-013161-022627_json', 'K-004378-005094-013161-023223_json', 'K-004378-005094-019552-037777_json', 'K-004378-005094-019552-038954_json', 'K-004378-005094-019552-044834_json', 'K-004378-005094-022627-037777_json', 'K-004378-005094-022627-038954_json', 'K-004378-005094-022627-044834_json', 'K-004378-005094-023223-037777_json', 'K-004378
# ...

# %%
import json
tmp_path = '/content/label/K-004378-005002-005094-023223_json'
example_file = open('/content/label/K-004378-005002-005094-023223_json/K-004378/K-004378-005002-005094-023223_0_2_0_2_70_000_200.json')
json_file = json.load(example_file)
annotations = json_file.get('annotations')
bbox = annotations[0].get('bbox')
print(bbox)
# Out:
# [136, 103, 213, 448]

# %%
import  cv2
from google.colab.patches import cv2_imshow
import  numpy as np

#Load image
img = cv2.imread('/content/image/K-004378-005002-005094-023223/K-004378-005002-005094-023223_0_2_0_2_70_000_200.png')

#Cropped data
print(bbox)
output = img[bbox[1]:bbox[1]+bbox[3], bbox[0]:bbox[0]+bbox[2]]
cv2.imwrite('/content/cropped.png',output)
# save result

copy_img = cv2.imread('/content/cropped.png')
cv2_imshow(copy_img)
# Out:
# [136, 103, 213, 448]
# <PIL.Image.Image image mode=RGB size=213x448 at 0x7FBB7A011A90>
